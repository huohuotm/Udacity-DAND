# %%
#!/usr/bin/python


import sys
import pickle
sys.path.append("../tools/")

from feature_format import featureFormat, targetFeatureSplit
from tester import dump_classifier_and_data

### Task 1: Select what features you'll use.
### features_list is a list of strings, each of which is a feature name.
### Load the dictionary containing the dataset
enron_dict = pickle.load(open("final_project_dataset.pkl", "r") )

### Explore the data
## what are the features?
features_explore = enron_dict[enron_dict.keys()[0]].keys()
#print features_explore 

## How many features?
print len(features_explore) # 21 features

## How many data points, NaNs, POIs etc?
# Out:
# 21
# /Users/weidian1/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# Create eda data frame
import pandas as pd
import numpy as np

### The first feature must be "poi".
features_list = ['poi', 'salary', 'to_messages', 'deferral_payments', 'total_payments', \
'exercised_stock_options', 'bonus', 'restricted_stock', 'shared_receipt_with_poi', \
'restricted_stock_deferred', 'total_stock_value', 'expenses', 'loan_advances', 'from_messages', \
'other', 'from_this_person_to_poi', 'director_fees', 'deferred_income', 'long_term_incentive', \
'from_poi_to_this_person'] 
#, 'email_address' removed

### Task 2: Remove outliers
### Outliers

## Remove Outliers entry from dictionary

outlier_keys = ['TOTAL', 'THE TRAVEL AGENCY IN THE PARK', 'LOCKHART EUGENE E']
for key in outlier_keys:
        enron_dict.pop(key, 0)

# %%
### Task 3: Create new feature(s)


# add two new features

# poi_interaction == total number of emails to and from a POI / 
#the total number of emails sent or received. 
#def add_financial_aggregate(my_dataset, my_feature_list)

# define email_fields
email_fields = ['to_messages', 'from_messages',
          'from_poi_to_this_person', 'from_this_person_to_poi']
# loop through data dict
for record in enron_dict:
    # set person as a value of a record 
    person = enron_dict[record]
    # new variable
    is_valid = True
    # loop through email fields
    for field in email_fields:
        # check if field value in enron_dict is NaN
        if person[field] == 'NaN':
            # set is_valid as false
            is_valid = False
    # check for when is_valid is true        
    if is_valid:
        # calculate field value
        total_messages = person['to_messages'] +\
                         person['from_messages']
        poi_messages = person['from_poi_to_this_person'] +\
                       person['from_this_person_to_poi']
        person['poi_interaction'] = float(poi_messages) / total_messages
    else:
        # set value as NaN
        person['poi_interaction'] = 'NaN'
# add to dictionary        
features_list += ['poi_interaction']

# remuneration == total payments + total stock value 
# to capture total wealth
#def add_financial_aggregate(data_dict, features_list):
    
financial_fields = ['total_payments', 'total_stock_value']
for record in enron_dict:
    person = enron_dict[record]
    is_valid = True
    for field in financial_fields:
        if person[field] == 'NaN':
            is_valid = False
    if is_valid:
        # sum every field defined in financial_fields
        person['remuneration'] = sum([person[field] for field in financial_fields])
    else:
        person['remuneration'] = 'NaN'
features_list += ['remuneration']

print features_list

print len(features_list)
# Out:
# ['poi', 'salary', 'to_messages', 'deferral_payments', 'total_payments', 'exercised_stock_options', 'bonus', 'restricted_stock', 'shared_receipt_with_poi', 'restricted_stock_deferred', 'total_stock_value', 'expenses', 'loan_advances', 'from_messages', 'other', 'from_this_person_to_poi', 'director_fees', 'deferred_income', 'long_term_incentive', 'from_poi_to_this_person', 'poi_interaction', 'remuneration']
# 22

# %%
### Store to my_dataset for easy export below.
my_dataset = enron_dict
my_feature_list = features_list

### Extract features and labels from dataset for local testing
data = featureFormat(my_dataset, my_feature_list)
labels, features = targetFeatureSplit(data)
#print labels, features

# %%
### Task 5: Tune your classifier to achieve better than .3 precision and recall 
### using our testing script. Check the tester.py script in the final project
### folder for details on the evaluation method, especially the test_classifier
### function. Because of the small size of the dataset, the script uses
### stratified shuffle split cross validation. For more info: 
### http://scikit-learn.org/stable/modules/generated/sklearn.cross_validation.StratifiedShuffleSplit.html

# parameter optimisation of algorithm using GridSearchCV

#trials = 1

# create score function
from sklearn.metrics import recall_score, precision_score, f1_score


from numpy import mean
import numpy as np
from sklearn import model_selection
from sklearn import metrics

def scorer(estimator, features_test, labels_test):
    labels_pred = estimator.predict(features_test)
    pre= precision_score(labels_test, labels_pred, average='micro')
    rec = recall_score(labels_test, labels_pred, average='micro')
    if pre>0.3 and rec>0.3:
        return f1_score(labels_test, labels_pred, average='macro')
    elif  pre>0.3 and rec<0.3:
        return 0.3
    elif rec >0.3 and pre<0.3:
        return 0.3
    return 0

# %%
## Create Cross Validation object for use in GridSearchCV  
from sklearn import model_selection
from sklearn.tree import DecisionTreeClassifier
from sklearn.grid_search import GridSearchCV
from sklearn.pipeline import Pipeline
sss = model_selection.StratifiedShuffleSplit(30, random_state = 42)

## State and Fit the model
#param_grid = [  {'n_estimators': [50,80,100]
#                 , 'learning_rate': [0.5,1,1.5,2]#,3,4,5]
#                 ,'base_estimator':[DecisionTreeClassifier(min_samples_split=2)
#                                    , DecisionTreeClassifier(min_samples_split=3)
#                                    , DecisionTreeClassifier(min_samples_split=4)]
#                }]

from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import AdaBoostClassifier
from sklearn.feature_selection import SelectKBest,chi2,f_classif
ada_clf = AdaBoostClassifier()
min_max_scaler = MinMaxScaler(feature_range=(0, 1))
kBest = SelectKBest()

pipe = Pipeline([('scaler', min_max_scaler),
                ('KBest', kBest ),
                ('ada_clf', ada_clf)]
                )
param_grid = {'KBest__k':range(4,11),'KBest__score_func':[chi2,f_classif]\
              ,'ada_clf__n_estimators':[50,80,100], 'ada_clf__learning_rate':[0.5,1.0,1.5,2]\
                     ,'ada_clf__base_estimator':[DecisionTreeClassifier(min_samples_split=2)\
                                                , DecisionTreeClassifier(min_samples_split=3)\
                                                , DecisionTreeClassifier(min_samples_split=4)]\
             }



my_clf = model_selection.GridSearchCV(pipe, param_grid, scoring = scorer, cv = sss, verbose=1, n_jobs=-1)
my_clf.fit(features, labels) 
print my_clf.best_estimator_
# Out:
# Fitting 30 folds for each of 504 candidates, totalling 15120 fits
# /Users/weidian1/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/weidian1/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/weidian1/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/weidian1/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [Parallel(n_jobs=-1)]: Done 180 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done 675 tasks      | elapsed:   21.2s
# [Parallel(n_jobs=-1)]: Done 1041 tasks      | elapsed:   51.6s
# [Parallel(n_jobs=-1)]: Done 1832 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 3016 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 4108 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 5499 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 7327 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done 8725 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done 10759 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done 13283 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=-1)]: Done 15120 out of 15120 | elapsed: 13.5min finished
# Pipeline(steps=[('scaler', MinMaxScaler(copy=True, feature_range=(0, 1))), ('KBest', SelectKBest(k=4, score_func=<function chi2 at 0x11303bf50>)), ('ada_clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#          ...om_state=None, splitter='best'),
#           learning_rate=1.5, n_estimators=100, random_state=None))])

# %%
 my_clf.best_estimator_.steps
# Out:
# [('scaler', MinMaxScaler(copy=True, feature_range=(0, 1))),
#  ('KBest', SelectKBest(k=4, score_func=<function chi2 at 0x11303bf50>)),
#  ('ada_clf', AdaBoostClassifier(algorithm='SAMME.R',
#             base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_split=1e-07, min_samples_leaf=1,
#               min_samples_split=3, min_weight_fraction_leaf=0.0,
#               presort=False, random_state=None, splitter='best'),
#             learning_rate=1.5, n_estimators=100, random_state=None))]

# %%
my_clf.best_estimator_.steps[1][1].scores_
# Out:
# array([  3.05278674e+00,   4.36397769e-01,   6.06966069e-02,
#          2.78477884e+00,   6.84550934e+00,   5.12075414e+00,
#          5.89535349e-01,   2.43221987e+00,   3.50676503e-03,
#          5.47661010e+00,   1.48610337e+00,   6.68878174e+00,
#          6.87385422e-02,   1.71595053e+00,   1.00080764e+00,
#          1.50113085e+00,   3.40099218e-01,   2.53848503e+00,
#          1.37005929e+00,   1.49803296e+00,   4.03774956e+00])

# %%
scores = my_clf.best_estimator_.steps[1][1].scores_
unsorted_pairs = zip(my_feature_list[1:], scores)
sorted_pairs = list(reversed(sorted(unsorted_pairs, key=lambda x: x[1])))
sorted_pairs
# Out:
# [('exercised_stock_options', 6.8455093350345679),
#  ('loan_advances', 6.6887817383422217),
#  ('total_stock_value', 5.4766100992860336),
#  ('bonus', 5.1207541370868066),
#  ('remuneration', 4.0377495619033237),
#  ('salary', 3.0527867447897892),
#  ('total_payments', 2.7847788396505124),
#  ('long_term_incentive', 2.5384850330808857),
#  ('shared_receipt_with_poi', 2.4322198651432254),
#  ('other', 1.7159505307994585),
#  ('director_fees', 1.5011308535948469),
#  ('poi_interaction', 1.4980329632584271),
#  ('expenses', 1.486103366663613),
#  ('from_poi_to_this_person', 1.3700592922294679),
#  ('from_this_person_to_poi', 1.0008076418017084),
#  ('restricted_stock', 0.58953534948658115),
#  ('to_messages', 0.43639776880238534),
#  ('deferred_income', 0.34009921840595764),
#  ('from_messages', 0.068738542151315835),
#  ('deferral_payments', 0.060696606931362404),
#  ('restricted_stock_deferred', 0.0035067650332055236)]

# %%
my_feature_list[1:]
# Out:
# ['salary',
#  'to_messages',
#  'deferral_payments',
#  'total_payments',
#  'exercised_stock_options',
#  'bonus',
#  'restricted_stock',
#  'shared_receipt_with_poi',
#  'restricted_stock_deferred',
#  'total_stock_value',
#  'expenses',
#  'loan_advances',
#  'from_messages',
#  'other',
#  'from_this_person_to_poi',
#  'director_fees',
#  'deferred_income',
#  'long_term_incentive',
#  'from_poi_to_this_person',
#  'poi_interaction',
#  'remuneration']

# %%
import tester
from tester import test_classifier
from sklearn.ensemble import AdaBoostClassifier
#ada_clf = AdaBoostClassifier()
#test_clf = AdaBoostClassifier(learning_rate=1.5, n_estimators=50
                             # ,base_estimator=DecisionTreeClassifier(min_samples_split=3,class_weight='balanced') )

tester.test_classifier(my_clf.best_estimator_, my_dataset, my_feature_list)
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler(copy=True, feature_range=(0, 1))), ('KBest', SelectKBest(k=4, score_func=<function chi2 at 0x11303bf50>)), ('ada_clf', AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#          ...om_state=None, splitter='best'),
#           learning_rate=1.5, n_estimators=100, random_state=None))])
# 	Accuracy: 0.84707	Precision: 0.41985	Recall: 0.38500	F1: 0.40167	F2: 0.39150
# 	Total predictions: 15000	True positives:  770	False positives: 1064	False negatives: 1230	True negatives: 11936

# %%
my_clf.grid_scores_
# Out:
# /Users/weidian1/anaconda/lib/python2.7/site-packages/sklearn/model_selection/_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# [mean: 0.59776, std: 0.14872, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 0.5, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.57640, std: 0.14685, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 0.5, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.57471, std: 0.15117, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 0.5, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.59281, std: 0.14209, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.0, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.58803, std: 0.14295, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.0, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.59976, std: 0.15190, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.0, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.60392, std: 0.16070, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.58741, std: 0.15519, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.58032, std: 0.15234, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.58004, std: 0.14531, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 2, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.58240, std: 0.14721, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 2, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.59732, std: 0.15115, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 2, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.60153, std: 0.15361, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 0.5, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.58016, std: 0.14312, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 0.5, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.57831, std: 0.14500, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 0.5, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.61469, std: 0.15102, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.0, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.61824, std: 0.15879, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.0, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.61981, std: 0.16553, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.0, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.63802, std: 0.17335, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.66426, std: 0.19712, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.64237, std: 0.15315, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.57512, std: 0.15688, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 2, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.60396, std: 0.14305, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 2, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.60356, std: 0.14308, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 2, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.64366, std: 0.18977, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 0.5, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.58256, std: 0.16866, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 0.5, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.60604, std: 0.17222, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 0.5, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.63964, std: 0.16343, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.0, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.67362, std: 0.17061, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.0, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.68208, std: 0.16650, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.0, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.63779, std: 0.15771, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.63382, std: 0.19781, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.63200, std: 0.15938, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.60094, std: 0.14644, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 2, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.60628, std: 0.14700, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 2, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.62850, std: 0.15032, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 2, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.57682, std: 0.16247, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 0.5, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.57286, std: 0.15863, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 0.5, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.58140, std: 0.16094, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 0.5, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.54931, std: 0.13548, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.0, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.56059, std: 0.15389, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.0, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.55114, std: 0.14972, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.0, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.56083, std: 0.14056, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.57312, std: 0.15843, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.58795, std: 0.15792, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.54377, std: 0.12545, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 2, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.55123, std: 0.13955, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 2, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.56046, std: 0.15183, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 2, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.56967, std: 0.15592, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 0.5, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.55133, std: 0.14649, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 0.5, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.54340, std: 0.12951, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 0.5, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.57440, std: 0.14711, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.0, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.55096, std: 0.13596, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.0, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.56051, std: 0.14498, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.0, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.56676, std: 0.15172, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.58060, std: 0.15382, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.60737, std: 0.15245, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.58442, std: 0.16334, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 2, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.56444, std: 0.14892, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 2, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.56089, std: 0.14016, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 2, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.57533, std: 0.15195, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 0.5, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.56273, std: 0.14651, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 0.5, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.55917, std: 0.15270, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 0.5, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.58882, std: 0.15432, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.0, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.60362, std: 0.15465, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.0, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.59489, std: 0.16707, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.0, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.58380, std: 0.15736, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.60191, std: 0.17753, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.59526, std: 0.15309, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.55596, std: 0.16471, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 2, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.56343, std: 0.14741, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 2, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.56953, std: 0.17123, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 4, 'ada_clf__learning_rate': 2, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.55259, std: 0.14437, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 5, 'ada_clf__learning_rate': 0.5, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.55928, std: 0.14849, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 5, 'ada_clf__learning_rate': 0.5, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.56966, std: 0.13794, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 5, 'ada_clf__learning_rate': 0.5, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.55836, std: 0.13379, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 5, 'ada_clf__learning_rate': 1.0, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.56588, std: 0.13900, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 5, 'ada_clf__learning_rate': 1.0, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.54407, std: 0.12534, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 5, 'ada_clf__learning_rate': 1.0, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.55070, std: 0.14683, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 5, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.54569, std: 0.13675, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 5, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.55610, std: 0.15358, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 5, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.55918, std: 0.15350, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 5, 'ada_clf__learning_rate': 2, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.57470, std: 0.15006, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 5, 'ada_clf__learning_rate': 2, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.56247, std: 0.14438, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 5, 'ada_clf__learning_rate': 2, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.53586, std: 0.14231, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 5, 'ada_clf__learning_rate': 0.5, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.57138, std: 0.14451, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 5, 'ada_clf__learning_rate': 0.5, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.53399, std: 0.12787, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 5, 'ada_clf__learning_rate': 0.5, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.55609, std: 0.15922, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 5, 'ada_clf__learning_rate': 1.0, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.60787, std: 0.15549, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 5, 'ada_clf__learning_rate': 1.0, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.65406, std: 0.15861, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 5, 'ada_clf__learning_rate': 1.0, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.60303, std: 0.15296, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 5, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.62004, std: 0.16550, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 5, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.58611, std: 0.14289, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 5, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function chi2 at 0x113049050>},
#  mean: 0.57659, std: 0.15110, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
# ...
#  mean: 0.53564, std: 0.11270, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 10, 'ada_clf__learning_rate': 1.0, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.54629, std: 0.14128, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 10, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.53693, std: 0.13164, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 10, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.55224, std: 0.12734, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 10, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.56242, std: 0.12918, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 10, 'ada_clf__learning_rate': 2, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.54918, std: 0.13377, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 10, 'ada_clf__learning_rate': 2, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.54307, std: 0.12697, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 10, 'ada_clf__learning_rate': 2, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.55834, std: 0.14363, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 10, 'ada_clf__learning_rate': 0.5, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.56202, std: 0.15521, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 10, 'ada_clf__learning_rate': 0.5, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.54604, std: 0.13672, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 10, 'ada_clf__learning_rate': 0.5, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.53165, std: 0.12556, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 10, 'ada_clf__learning_rate': 1.0, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.52814, std: 0.13152, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 10, 'ada_clf__learning_rate': 1.0, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.52918, std: 0.13301, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 10, 'ada_clf__learning_rate': 1.0, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.56864, std: 0.15130, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 10, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.54096, std: 0.16333, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 10, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.53115, std: 0.15250, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 10, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.57777, std: 0.13438, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 10, 'ada_clf__learning_rate': 2, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.56692, std: 0.14564, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 10, 'ada_clf__learning_rate': 2, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.56001, std: 0.14383, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 10, 'ada_clf__learning_rate': 2, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.60106, std: 0.16226, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 10, 'ada_clf__learning_rate': 0.5, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.56711, std: 0.16442, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 10, 'ada_clf__learning_rate': 0.5, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.58412, std: 0.16110, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 10, 'ada_clf__learning_rate': 0.5, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.51963, std: 0.12958, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 10, 'ada_clf__learning_rate': 1.0, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.51341, std: 0.13247, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 10, 'ada_clf__learning_rate': 1.0, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.55486, std: 0.16377, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 10, 'ada_clf__learning_rate': 1.0, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.55039, std: 0.15922, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 10, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.54812, std: 0.15273, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 10, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.54831, std: 0.14816, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 10, 'ada_clf__learning_rate': 1.5, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.54183, std: 0.13934, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 10, 'ada_clf__learning_rate': 2, 'ada_clf__n_estimators': 50, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.55115, std: 0.13822, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 10, 'ada_clf__learning_rate': 2, 'ada_clf__n_estimators': 80, 'KBest__score_func': <function f_classif at 0x113016ed8>},
#  mean: 0.52517, std: 0.13060, params: {'ada_clf__base_estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), 'KBest__k': 10, 'ada_clf__learning_rate': 2, 'ada_clf__n_estimators': 100, 'KBest__score_func': <function f_classif at 0x113016ed8>}]

# %%
from tester import dump_classifier_and_data

### Final and parameter tuned algorithm
#clf = my_clf.best_estimator_
clf = AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
          learning_rate=1.5, n_estimators=100, random_state=None)

### Task 6: Dump your classifier, dataset, and features_list so anyone can
### check your results. You do not need to change anything below, but make sure
### that the version of poi_id.py that you submit can be run on its own and
### generates the necessary .pkl files for validating your results.

dump_classifier_and_data(clf, my_dataset, my_feature_list)


# https://www.kaggle.com/forums/f/15/kaggle-forum/t/4092/how-to-tune-rf-parameters-in-practice
# /Users/andreasvoniatismbp10/Documents/Dropbox/ARTIOS/Training/git_github/version-control/ud120-projects/final_project
# https://discussions.udacity.com/t/showing-the-best-estimator-from-grid-search-cv/194547/5

# %%
my_feature_list
# Out:
# ['poi',
#  'salary',
#  'total_payments',
#  'bonus',
#  'shared_receipt_with_poi',
#  'exercised_stock_options',
#  'from_messages',
#  'other',
#  'from_this_person_to_poi',
#  'long_term_incentive',
#  'expenses',
#  'restricted_stock']

# %%
len(my_dataset)
# Out:
# 143
